# %% [markdown]
# <a href="https://colab.research.google.com/github/sadmantamzid/ML/blob/main/exercises_chapter_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Qubits - Exercises
#
# The fundamental units of information in quantum computing are called qubits (quantum bits). Similar to classical bits, qubits can be found in states 0 and 1, but they can also exist in linear combinations of both.
#
# In the standard notation for quantum information, known as Dirac notation, the quantum 0 and 1 states are represented as $\ket{0}$ and $\ket{1}$, where the symbol $\ket{\ }$ denotes a quantum state instead of a classical state. The states $\ket{0}$ and $\ket{1}$, also called computational states, represent a classical bit. For a general quantum state, we can write:
#
# $$
# |\psi\rangle = \begin{bmatrix}
#     \alpha \\
#     \beta \\
# \end{bmatrix}.
# $$
#
# In other words, a ket is just a column vector, exactly like a classical probability vector. Instead of putting an arrow over the name of the variable to express that it is a vector, we use the ket to say that it is a column vector that represents a quantum state.
#
# The key difference between classical probability distributions and quantum states is the normalization constraint. In quantum states, the square sum of their absolute values adds up to 1:
#
# $$
# \sqrt{|\alpha|^2 + |\beta|^2} = 1,
# $$
#
# where the components of the quantum state vector, which we call *probability amplitudes*, are complex valued.

# %%
pip install ingenii-quantum
# Out:
# Collecting ingenii-quantum
#   Downloading ingenii_quantum-0.1.1-py3-none-any.whl.metadata (7.2 kB)
# Collecting qiskit>=1.2 (from ingenii-quantum)
#   Downloading qiskit-2.0.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting qiskit-aer>=0.15 (from ingenii-quantum)
#   Downloading qiskit_aer-0.17.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.2 kB)
# Collecting qiskit-ibm-runtime>=0.31 (from ingenii-quantum)
#   Downloading qiskit_ibm_runtime-0.37.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from ingenii-quantum) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from ingenii-quantum) (1.14.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from ingenii-quantum) (3.13.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from ingenii-quantum) (3.10.0)
# Collecting pylatexenc (from ingenii-quantum)
#   Downloading pylatexenc-2.10.tar.gz (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 4.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from ingenii-quantum) (2.6.0+cu124)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.11/dist-packages (from ingenii-quantum) (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from ingenii-quantum) (0.21.0+cu124)
# Collecting torch-geometric (from ingenii-quantum)
#   Downloading torch_geometric-2.6.1-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 3.6 MB/s eta 0:00:00
# Collecting pennylane (from ingenii-quantum)
#   Downloading PennyLane-0.40.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (from ingenii-quantum) (2.18.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from ingenii-quantum) (2.0.2)
# Collecting tensorly (from ingenii-quantum)
#   Downloading tensorly-0.9.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting quimb (from ingenii-quantum)
#   Downloading quimb-1.10.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting gurobipy (from ingenii-quantum)
#   Downloading gurobipy-12.0.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (16 kB)
# Collecting rustworkx>=0.15.0 (from qiskit>=1.2->ingenii-quantum)
#   Downloading rustworkx-0.16.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: sympy>=1.3 in /usr/local/lib/python3.11/dist-packages (from qiskit>=1.2->ingenii-quantum) (1.13.1)
# Collecting dill>=0.3 (from qiskit>=1.2->ingenii-quantum)
#   Downloading dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from qiskit>=1.2->ingenii-quantum) (2.8.2)
# Collecting stevedore>=3.0.0 (from qiskit>=1.2->ingenii-quantum)
#   Downloading stevedore-5.4.1-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from qiskit>=1.2->ingenii-quantum) (4.13.1)
# Collecting symengine<0.14,>=0.11 (from qiskit>=1.2->ingenii-quantum)
#   Downloading symengine-0.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.11/dist-packages (from qiskit-aer>=0.15->ingenii-quantum) (5.9.5)
# Requirement already satisfied: requests>=2.19 in /usr/local/lib/python3.11/dist-packages (from qiskit-ibm-runtime>=0.31->ingenii-quantum) (2.32.3)
# Collecting requests-ntlm>=1.1.0 (from qiskit-ibm-runtime>=0.31->ingenii-quantum)
#   Downloading requests_ntlm-1.3.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from qiskit-ibm-runtime>=0.31->ingenii-quantum) (2.3.0)
# Requirement already satisfied: websocket-client>=1.5.1 in /usr/local/lib/python3.11/dist-packages (from qiskit-ibm-runtime>=0.31->ingenii-quantum) (1.8.0)
# Collecting ibm-platform-services>=0.22.6 (from qiskit-ibm-runtime>=0.31->ingenii-quantum)
#   Downloading ibm_platform_services-0.63.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting pydantic<2.10,>=2.5.0 (from qiskit-ibm-runtime>=0.31->ingenii-quantum)
#   Downloading pydantic-2.9.2-py3-none-any.whl.metadata (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.4/149.4 kB 9.9 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from qiskit-ibm-runtime>=0.31->ingenii-quantum) (24.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->ingenii-quantum) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->ingenii-quantum) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->ingenii-quantum) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->ingenii-quantum) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->ingenii-quantum) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->ingenii-quantum) (3.2.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from pennylane->ingenii-quantum) (3.4.2)
# Requirement already satisfied: autograd in /usr/local/lib/python3.11/dist-packages (from pennylane->ingenii-quantum) (1.7.0)
# Collecting tomlkit (from pennylane->ingenii-quantum)
#   Downloading tomlkit-0.13.2-py3-none-any.whl.metadata (2.7 kB)
# Collecting appdirs (from pennylane->ingenii-quantum)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting autoray>=0.6.11 (from pennylane->ingenii-quantum)
#   Downloading autoray-0.7.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.11/dist-packages (from pennylane->ingenii-quantum) (5.5.2)
# Collecting pennylane-lightning>=0.40 (from pennylane->ingenii-quantum)
#   Downloading PennyLane_Lightning-0.40.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (27 kB)
# Collecting diastatic-malt (from pennylane->ingenii-quantum)
#   Downloading diastatic_malt-2.15.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting cotengra>=0.6.1 (from quimb->ingenii-quantum)
#   Downloading cotengra-0.7.2-py3-none-any.whl.metadata (17 kB)
# Collecting cytoolz>=0.8.0 (from quimb->ingenii-quantum)
#   Downloading cytoolz-1.0.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.6 kB)
# Requirement already satisfied: numba>=0.39 in /usr/local/lib/python3.11/dist-packages (from quimb->ingenii-quantum) (0.60.0)
# Requirement already satisfied: tqdm>=4 in /usr/local/lib/python3.11/dist-packages (from quimb->ingenii-quantum) (4.67.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->ingenii-quantum) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->ingenii-quantum) (3.6.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->ingenii-quantum) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->ingenii-quantum) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow->ingenii-quantum) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->ingenii-quantum) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->ingenii-quantum) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->ingenii-quantum) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow->ingenii-quantum) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow->ingenii-quantum) (5.29.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow->ingenii-quantum) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->ingenii-quantum) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->ingenii-quantum) (3.0.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->ingenii-quantum) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow->ingenii-quantum) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow->ingenii-quantum) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->ingenii-quantum) (3.8.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->ingenii-quantum) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->ingenii-quantum) (0.37.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->ingenii-quantum) (3.18.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->ingenii-quantum) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->ingenii-quantum) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch->ingenii-quantum)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch->ingenii-quantum)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch->ingenii-quantum)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch->ingenii-quantum)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch->ingenii-quantum)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch->ingenii-quantum)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch->ingenii-quantum)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch->ingenii-quantum)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch->ingenii-quantum)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->ingenii-quantum) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->ingenii-quantum) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->ingenii-quantum) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch->ingenii-quantum)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->ingenii-quantum) (3.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy>=1.3->qiskit>=1.2->ingenii-quantum) (1.3.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from torch-geometric->ingenii-quantum) (3.11.15)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow->ingenii-quantum) (0.45.1)
# Requirement already satisfied: toolz>=0.8.0 in /usr/local/lib/python3.11/dist-packages (from cytoolz>=0.8.0->quimb->ingenii-quantum) (0.12.1)
# Collecting ibm_cloud_sdk_core<4.0.0,>=3.22.1 (from ibm-platform-services>=0.22.6->qiskit-ibm-runtime>=0.31->ingenii-quantum)
#   Downloading ibm_cloud_sdk_core-3.23.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow->ingenii-quantum) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow->ingenii-quantum) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow->ingenii-quantum) (0.14.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.39->quimb->ingenii-quantum) (0.43.0)
# Collecting scipy-openblas32>=0.3.26 (from pennylane-lightning>=0.40->pennylane->ingenii-quantum)
#   Downloading scipy_openblas32-0.3.29.0.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.1/56.1 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<2.10,>=2.5.0->qiskit-ibm-runtime>=0.31->ingenii-quantum) (0.7.0)
# Collecting pydantic-core==2.23.4 (from pydantic<2.10,>=2.5.0->qiskit-ibm-runtime>=0.31->ingenii-quantum)
#   Downloading pydantic_core-2.23.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19->qiskit-ibm-runtime>=0.31->ingenii-quantum) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19->qiskit-ibm-runtime>=0.31->ingenii-quantum) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19->qiskit-ibm-runtime>=0.31->ingenii-quantum) (2025.1.31)
# Requirement already satisfied: cryptography>=1.3 in /usr/local/lib/python3.11/dist-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime>=0.31->ingenii-quantum) (43.0.3)
# Collecting pyspnego>=0.4.0 (from requests-ntlm>=1.1.0->qiskit-ibm-runtime>=0.31->ingenii-quantum)
#   Downloading pyspnego-0.11.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting pbr>=2.0.0 (from stevedore>=3.0.0->qiskit>=1.2->ingenii-quantum)
#   Downloading pbr-6.1.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow->ingenii-quantum) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow->ingenii-quantum) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow->ingenii-quantum) (3.1.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch-geometric->ingenii-quantum) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch-geometric->ingenii-quantum) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch-geometric->ingenii-quantum) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch-geometric->ingenii-quantum) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch-geometric->ingenii-quantum) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch-geometric->ingenii-quantum) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch-geometric->ingenii-quantum) (1.18.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->ingenii-quantum) (3.0.2)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime>=0.31->ingenii-quantum) (1.17.1)
# Requirement already satisfied: PyJWT<3.0.0,>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from ibm_cloud_sdk_core<4.0.0,>=3.22.1->ibm-platform-services>=0.22.6->qiskit-ibm-runtime>=0.31->ingenii-quantum) (2.10.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow->ingenii-quantum) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow->ingenii-quantum) (2.18.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime>=0.31->ingenii-quantum) (2.22)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow->ingenii-quantum) (0.1.2)
# Downloading ingenii_quantum-0.1.1-py3-none-any.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 10.7 MB/s eta 0:00:00
# Downloading qiskit-2.0.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 84.7 MB/s eta 0:00:00
# Downloading qiskit_aer-0.17.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 67.5 MB/s eta 0:00:00
# Downloading qiskit_ibm_runtime-0.37.0-py3-none-any.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 54.5 MB/s eta 0:00:00
# Downloading gurobipy-12.0.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (14.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.4/14.4 MB 56.0 MB/s eta 0:00:00
# Downloading PennyLane-0.40.0-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 54.7 MB/s eta 0:00:00
# Downloading quimb-1.10.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 47.0 MB/s eta 0:00:00
# Downloading tensorly-0.9.0-py3-none-any.whl (7.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 67.8 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 21.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 15.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 24.1 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.4 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.2 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.5 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.7 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 56.1 MB/s eta 0:00:00
# Downloading torch_geometric-2.6.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 49.5 MB/s eta 0:00:00
# Downloading autoray-0.7.1-py3-none-any.whl (930 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 930.8/930.8 kB 45.1 MB/s eta 0:00:00
# Downloading cotengra-0.7.2-py3-none-any.whl (192 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.7/192.7 kB 13.0 MB/s eta 0:00:00
# Downloading cytoolz-1.0.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 70.2 MB/s eta 0:00:00
# Downloading dill-0.3.9-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.4/119.4 kB 7.4 MB/s eta 0:00:00
# Downloading ibm_platform_services-0.63.0-py3-none-any.whl (352 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 353.0/353.0 kB 22.4 MB/s eta 0:00:00
# Downloading PennyLane_Lightning-0.40.0-cp311-cp311-manylinux_2_28_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 66.0 MB/s eta 0:00:00
# Downloading pydantic-2.9.2-py3-none-any.whl (434 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.9/434.9 kB 27.2 MB/s eta 0:00:00
# Downloading pydantic_core-2.23.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 68.1 MB/s eta 0:00:00
# Downloading requests_ntlm-1.3.0-py3-none-any.whl (6.6 kB)
# Downloading rustworkx-0.16.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 58.6 MB/s eta 0:00:00
# Downloading stevedore-5.4.1-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 3.1 MB/s eta 0:00:00
# Downloading symengine-0.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 MB 14.9 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading diastatic_malt-2.15.2-py3-none-any.whl (167 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 kB 11.8 MB/s eta 0:00:00
# Downloading tomlkit-0.13.2-py3-none-any.whl (37 kB)
# Downloading ibm_cloud_sdk_core-3.23.0-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.5/69.5 kB 4.4 MB/s eta 0:00:00
# Downloading pbr-6.1.1-py2.py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.0/109.0 kB 7.8 MB/s eta 0:00:00
# Downloading pyspnego-0.11.2-py3-none-any.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.5/130.5 kB 8.3 MB/s eta 0:00:00
# Downloading scipy_openblas32-0.3.29.0.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 88.0 MB/s eta 0:00:00
# Building wheels for collected packages: pylatexenc
#   Building wheel for pylatexenc (setup.py) ... done
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136817 sha256=6eb320d936911c35c78d4c617033e326281d192696f90e39a7c4493491ab3f45
#   Stored in directory: /root/.cache/pip/wheels/b1/7a/33/9fdd892f784ed4afda62b685ae3703adf4c91aa0f524c28f03
# Successfully built pylatexenc
# Installing collected packages: pylatexenc, appdirs, tomlkit, symengine, scipy-openblas32, rustworkx, pydantic-core, pbr, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, gurobipy, dill, cytoolz, autoray, tensorly, stevedore, pydantic, nvidia-cusparse-cu12, nvidia-cudnn-cu12, ibm_cloud_sdk_core, diastatic-malt, cotengra, torch-geometric, quimb, qiskit, pyspnego, nvidia-cusolver-cu12, ibm-platform-services, requests-ntlm, qiskit-aer, qiskit-ibm-runtime, pennylane-lightning, pennylane, ingenii-quantum
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.33.1
#     Uninstalling pydantic_core-2.33.1:
#       Successfully uninstalled pydantic_core-2.33.1
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.11.2
#     Uninstalling pydantic-2.11.2:
#       Successfully uninstalled pydantic-2.11.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed appdirs-1.4.4 autoray-0.7.1 cotengra-0.7.2 cytoolz-1.0.1 diastatic-malt-2.15.2 dill-0.3.9 gurobipy-12.0.1 ibm-platform-services-0.63.0 ibm_cloud_sdk_core-3.23.0 ingenii-quantum-0.1.1 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 pbr-6.1.1 pennylane-0.40.0 pennylane-lightning-0.40.0 pydantic-2.9.2 pydantic-core-2.23.4 pylatexenc-2.10 pyspnego-0.11.2 qiskit-2.0.0 qiskit-aer-0.17.0 qiskit-ibm-runtime-0.37.0 quimb-1.10.0 requests-ntlm-1.3.0 rustworkx-0.16.0 scipy-openblas32-0.3.29.0.0 stevedore-5.4.1 symengine-0.13.0 tensorly-0.9.0 tomlkit-0.13.2 torch-geometric-2.6.1

# %% [markdown]
# Let's start by creating and visualizing the basis state $\ket{0}$ using `qiskit`. The following code creates a quantum circuit with 1 qubit, which is automatically initialized to the $\ket{0}$ state. We then retrieve the statevector and plot it in the bloch sphere.

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from ingenii_quantum.visualizer import QuantumVisualizer
from ingenii_quantum.exercises import *
import numpy as np

# Build quantum circuit
qc = QuantumCircuit(1)
# Get statevector
vector = Statevector(qc)
visualizer = QuantumVisualizer(qc)
print('Statevector: ', np.array(vector))
# Plot Bloch Sphere
visualizer.draw_bloch_sphere()
# Out:
# /usr/local/lib/python3.11/dist-packages/cotengra/hyperoptimizers/hyper.py:54: UserWarning: Couldn't find `optuna`, `cmaes`, or `nevergrad` so will use completely random sampling in place of hyper-optimization.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/cotengra/hyperoptimizers/hyper.py:73: UserWarning: Couldn't find `optuna`, `cmaes`, or `nevergrad` so will use completely random sampling in place of hyper-optimization.
#   warnings.warn(
# Statevector:  [1.+0.j 0.+0.j]

# %% [markdown]
# We can also initialize the quantum circuit directly in a different state. In future lessons, we will learn how to use quantum gates to modify quantum states. Let's initialize the circuit in the $\ket{1}$ state, which corresponds to the vector $\begin{pmatrix} 0 \\ 1 \end{pmatrix}$

# %%
# Build quantum circuit
qc = QuantumCircuit(1)
# Initialize quantum circuit
initial_state = np.array([0., 1.])
qc.initialize(initial_state)
# Get quantum vector
vector = Statevector(qc)
visualizer = QuantumVisualizer(qc)

print('Statevector: ', np.array(vector))
# Plot Bloch Sphere
visualizer.draw_bloch_sphere()
# Out:
# Statevector:  [0.+0.j 1.+0.j]
# /usr/local/lib/python3.11/dist-packages/ingenii_quantum/visualizer.py:216: UserWarning: Initialize operation not implemented for state space vizualization.
#   warnings.warn('Initialize operation not implemented for state space vizualization.')

# %% [markdown]
# ### Exercise 1
#
# Initialize the quantum circuit in the $ \ket{+} = \frac{1}{\sqrt{2}} (\ket{0} + \ket{1}) $ state.

# %%
## Your code here
########################################################

########################################################
qc = QuantumCircuit(1)

initial_state=np.array([1/np.sqrt(2), 1/np.sqrt(2)])
qc.initialize(initial_state)
vector = Statevector(qc)
visualizer = QuantumVisualizer(qc)

#exercise2_1(vector)
print('Statevector: ', np.array(vector))
visualizer.draw_bloch_sphere()
# Out:
# Statevector:  [0.70710678+0.j 0.70710678+0.j]
# /usr/local/lib/python3.11/dist-packages/ingenii_quantum/visualizer.py:216: UserWarning: Initialize operation not implemented for state space vizualization.
#   warnings.warn('Initialize operation not implemented for state space vizualization.')

# %% [markdown]
# ### Exercise 2
# Initialize a quantum circuit with a superposition state such that $P(\ket{0}) = 0.25$ and $P(\ket{1}) = 0.75$.

# %%
## Your code here
########################################################

########################################################

qc = QuantumCircuit(1, 1)
qc.ry(2 * np.pi / 3, 0)  # Apply R_y(2π/3) to create the desired superposition
qc.measure(0, 0)
print('Statevector: ', np.array(vector))
visualizer.draw_bloch_sphere()
# Out:
# Statevector:  [0.70710678+0.j 0.70710678+0.j]

# %% [markdown]
# ### Exercise 3
# Initialize a quantum circuit in a superposition state such that $\phi = \pi$ and $\theta = \pi/2$.

# %%
## Your code here
########################################################

########################################################
qc = QuantumCircuit(1, 1)
qc.ry(np.pi/2, 0)  # Set θ = π/2
qc.rz(np.pi, 0)    # Set ϕ = π
qc.measure(0, 0)
#exercise2_3(vector)

print('Statevector: ', np.array(vector))
visualizer.draw_bloch_sphere()
# Out:
# Statevector:  [0.70710678+0.j 0.70710678+0.j]

# %% [markdown]
# ## Quantum measurement
#
# Obtaining information about a quantum state is known as performing a measurement. When we measure a qubit, we only obtain a single bit of information. Measurement collapses superposition states, allowing us to observe only the computational basis states $\ket{0}$ or $\ket{1}$ instead of observing superpositions directly.
#
# While the measurement outcome is random, it follows the probabilities dictated by quantum mechanics. The coefficients $|\alpha|^2$ and $|\beta|^2$ represent the probabilities of measuring $\ket{0}$ or $\ket{1}$, respectively. The normalization condition of the quantum state ensures that these probabilities add up to 1:
#
# $$
# |\alpha|^2 + |\beta|^2 = 1.
# $$
#
# In a real setting, multiple measurements of the same quantum state (preparing it anew each time) are performed to estimate these probabilities. In Qiskit, we can visualize this process using a histogram that shows the frequency of outcomes for $\ket{0}$ and $\ket{1}$ based on repeated measurements. To perform measurements, we need to add classical registers to retrieve the output of the measurements. In the following example, we include one quantum register and one classical register, and we measure a quantum circuit initialized to the $\ket{0}$ state. In this example, we use a classical simulator to perform the experiments. Notice that we set the parameter `shots=1024`, which determines the number of runs.

# %%
from qiskit import ClassicalRegister, QuantumRegister, transpile
from qiskit_aer import Aer
from qiskit.visualization import plot_histogram

q = QuantumRegister(2)
c = ClassicalRegister(2)
circuit = QuantumCircuit(q, c)
# Measure qubit qubit q in register c
circuit.measure(q,c)
# Use Simulator to run the circuit
simulator = Aer.get_backend('aer_simulator')
circuit = transpile(circuit, simulator)
# Execute the circuit on the simulator
result = simulator.run(circuit, backend=simulator, shots=1024).result()
# Get the measurement counts
counts = result.get_counts(circuit)

plot_histogram(counts)

# %% [markdown]
# ### Exercise 4
#
# Plot the histogram of a quantum circuit initialized to the maximally entangled state of two qubits, $ \ket{\Phi} = \frac{1}{\sqrt{2}} (\ket{00} + \ket{11})$. Use `4096` shots to run the experiment.

# %%
from qiskit import ClassicalRegister, QuantumRegister, transpile, QuantumCircuit
from qiskit_aer import Aer
from qiskit.visualization import plot_histogram
import numpy as np


# Create a quantum circuit with 2 qubits
qc = QuantumCircuit(2,2)

# Create the entangled state (Bell state |Phi+>)
qc.h(0)  # Apply Hadamard gate to the first qubit
qc.cx(0, 1)  # Apply CNOT gate (control: qubit 0, target: qubit 1)
qc.measure([0, 1], [0, 1])

q = QuantumRegister(2)
c = ClassicalRegister(2)
circuit = QuantumCircuit(q, c)



# Measure the qubits
circuit.measure(q, c)

# Use the Aer simulator
simulator = Aer.get_backend('aer_simulator')
circuit = transpile(circuit, simulator)

# Execute the circuit with 4096 shots
result = simulator.run(qc, backend=simulator, shots=4096).result()

# Get the measurement counts
counts = result.get_counts(qc)

# Plot the histogram of the results
plot_histogram(counts)

# %%
from qiskit import QuantumCircuit
from qiskit_aer import Aer
from qiskit.visualization import plot_histogram

qc = QuantumCircuit(3, 3)
qc.h(0)
qc.cx(0,1)
qc.cx(0,2)
qc.measure([0,1,2],[0,1,2])
simulator = Aer.get_backend('aer_simulator')
result = simulator.run(qc, shots=2000).result()

# Step 4: Plot the histogram
counts = result.get_counts()
plot_histogram(counts)

# %% [markdown]
# ## Q-sphere representation
#
# Visualizing the state of multiple qubits can be challenging due to the high dimensionality of the quantum state space. Similar to how the Bloch Sphere aids in one-qubit visualizations, the Q-sphere provides an intuitive way to understand the distribution of a quantum state's probability amplitudes and phases for multiple-qubit systems. Recall that the general formula for a multiple-qubit state is:
#
# $$
# \ket{\Psi} = \sum_{i=0}^{2^n-1} \alpha_i \ket{i}
# $$
#
# In the Q-sphere representation:
#
# - Each computational basis state $\ket{i}$ is shown as a point on the sphere.
# - The radius of each point represents the probability of that state, given by $|\alpha_i|^2$. Larger points mean higher probabilities.
# - The color of each point indicates the phase of the coefficient $\arg(\alpha_i)$, which is a complex number with a modulus of 1. As shown by the color legend, different phases are represented by different colors (e.g., +1 is gray, -1 is purple, $i$ is green, and $-i$ is yellow).
# - The latitude of each point on the sphere shows the number of 0s and 1s in the state. States with the same number of 0s and 1s will be at the same latitude.
#
# This visualization helps you see how the probabilities and phases are distributed across different states in a multi-qubit system. Let's see how to visualize a superposition state with different phases: $ \ket{\Psi} = \frac{1}{2} (i\ket{00} - i\ket{01} - \ket{10} + \ket{11}) $

# %%
initial_state = 1/2*np.array([1j, -1j, -1, 1])

qc = QuantumCircuit(2)
qc.initialize(initial_state)
visualizer = QuantumVisualizer(qc)

visualizer.draw_qsphere()
# Out:
# /usr/local/lib/python3.11/dist-packages/ingenii_quantum/visualizer.py:216: UserWarning: Initialize operation not implemented for state space vizualization.
#   warnings.warn('Initialize operation not implemented for state space vizualization.')

# %% [markdown]
# ### Exercise 5
#
# Create a quantum circuit that generates this three-qubit circuit $ \ket{\Psi} = i\sqrt(0.5)\ket{000} - \sqrt(0.3)\ket{011} + \sqrt(0.2)\ket{11}$

# %%
import numpy as np
from qiskit import QuantumCircuit
from qiskit_aer import Aer
from qiskit.visualization import plot_histogram
from qiskit.visualization import plot_bloch_multivector
from ingenii_quantum.visualizer import QuantumVisualizer

initial_state=np.array([1j*np.sqrt(0.5),0,0,-1*np.sqrt(0.3),0,0,0,np.sqrt(0.2)])
qc = QuantumCircuit(3)
qc.initialize(initial_state)
qc.measure_all()
simulator = Aer.get_backend('aer_simulator')
result = simulator.run(qc, shots=2000).result()
#visualizer = QuantumVisualizer(qc)
#visualizer.draw_qsphere()

counts = result.get_counts()
plot_histogram(counts)
